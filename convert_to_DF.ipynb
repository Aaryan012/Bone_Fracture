# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
fact_img=r"C:\Users\rnkha\OneDrive\Desktop\Gajedi\bone_fracture\combine"

# %%
os.listdir(fact_img)
# Out:
# ['combine_fracture', 'non_fracture']

# %%
lables=os.listdir(fact_img)
lables
# Out:
# ['combine_fracture', 'non_fracture']

# %%
# get dictionary with Label names
label_path_dict=dict.fromkeys(lables)
label_path_dict
# Out:
# {'combine_fracture': None, 'non_fracture': None}

# %%
for label in label_path_dict.keys():
    lbl_path=os.path.join(fact_img,label)
    img_path=[os.path.join(lbl_path,img)for img in os.listdir(lbl_path)]
    label_path_dict[label]=img_path

# %%
label_path_dict['non_fracture']=label_path_dict['non_fracture'][160:]

# %%
pd.DataFrame(label_path_dict).to_csv('Image_labels_path.csv',index=False)
